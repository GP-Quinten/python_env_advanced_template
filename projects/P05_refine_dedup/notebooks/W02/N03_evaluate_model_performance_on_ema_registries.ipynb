# %% [markdown]
# # EMA Registries: Nearest Neighbor Assignment (Option 1)
#
# This notebook implements and analyzes the nearest neighbor assignment approach for landing EMA registries into existing clusters.

# %% [markdown]
# ## 1. Setup & Imports

# %%
import os
import os
working_dir = "/home/gpinon/more_europa/clean_rdc_experiments/projects/P05_refine_dedup"
os.chdir(working_dir)
print(f"Changed working directory to {working_dir}")
import pandas as pd
import numpy as np
from pathlib import Path
import logging
from tqdm import tqdm
from src.p05_refine_dedup import config
from src.p05_refine_dedup.utils.s3_io_functions import load_parquet_from_s3
# Out:
# Changed working directory to /home/gpinon/more_europa/clean_rdc_experiments/projects/P05_refine_dedup

# %% [markdown]
# ## 2. Load Data

# %%
# a. Load registry embeddings from S3
s3_input_embeddings = "registry_data_catalog_experiments/P05_refine_dedup/registry_names_embeddings.parquet"
bucket_name = config.BUCKET_NAME_DEV
folder_path = s3_input_embeddings.rsplit('/', 1)[0]
file_name = s3_input_embeddings.rsplit('/', 1)[-1]
embeddings_df = load_parquet_from_s3(
    bucket_name=bucket_name,
    folder_path=folder_path,
    file_name=file_name,
)
print(f'Loaded registry embeddings: {embeddings_df.shape}')
# Out:
# WARNING:root:Data will be loaded from s3://s3-common-dev20231214174437248800000002/registry_data_catalog_experiments/P05_refine_dedup/registry_names_embeddings.parquet
# Loaded registry embeddings: (54335, 4)

# %%
# b. Load cluster assignments from local Excel
clusters_table_xlsx = 'data/W02/R02_evaluate_model_performance/clusters_table.xlsx'
clusters_df = pd.read_excel(clusters_table_xlsx)
print(f'Loaded clusters table: {clusters_df.shape}')
# Out:
# Loaded clusters table: (54335, 3)

# %%
# c. Load EMA registry embeddings from S3
s3_ema_embeddings = 'registry_data_catalog_experiments/P05_refine_dedup/ema_registry_names_embeddings.parquet'
ema_folder_path = s3_ema_embeddings.rsplit('/', 1)[0]
ema_file_name = s3_ema_embeddings.rsplit('/', 1)[-1]
ema_embeddings_df = load_parquet_from_s3(
    bucket_name=bucket_name,
    folder_path=ema_folder_path,
    file_name=ema_file_name,
)
print(f'Loaded EMA registry embeddings: {ema_embeddings_df.shape}')
# Out:
# WARNING:root:Data will be loaded from s3://s3-common-dev20231214174437248800000002/registry_data_catalog_experiments/P05_refine_dedup/ema_registry_names_embeddings.parquet
# Loaded EMA registry embeddings: (237, 4)

# %% [markdown]
# ## 3. Preprocessing
# No normalization required. Ensure embeddings are in correct format.

# %%
# Ensure embeddings are numpy arrays
embeddings_df['full_name_embedding'] = embeddings_df['full_name_embedding'].apply(np.array)
ema_embeddings_df['full_name_embedding'] = ema_embeddings_df['full_name_embedding'].apply(np.array)
clusters_df['Final_Cluster'] = clusters_df['Final_Cluster'].astype(str)
print('Embeddings and clusters preprocessed.')
# Out:
# Embeddings and clusters preprocessed.

# %% [markdown]
# ## 4. Nearest Neighbor Search and Results Table

# %%
from sklearn.metrics.pairwise import cosine_distances
# Prepare lookup tables
emb_matrix = np.vstack(embeddings_df['full_name_embedding'].values)
ema_matrix = np.vstack(ema_embeddings_df['full_name_embedding'].values)
# Add cluster info to embeddings_df
embeddings_with_clusters = embeddings_df.merge(clusters_df, on=['full_name', 'number_of_occurrences'], how='left')
# For each EMA registry, find nearest neighbor and cluster info
results = []
for idx, ema_row in tqdm(ema_embeddings_df.iterrows(), total=ema_embeddings_df.shape[0]):
    ema_emb = ema_row['full_name_embedding'].reshape(1, -1)
    dists = cosine_distances(ema_emb, emb_matrix)[0]
    min_idx = np.argmin(dists)
    closest_row = embeddings_with_clusters.iloc[min_idx]
    assigned_cluster = closest_row['Final_Cluster']
    # Get all aliases in the same cluster
    cluster_aliases = embeddings_with_clusters[embeddings_with_clusters['Final_Cluster'] == assigned_cluster]
    total_aliases = cluster_aliases.shape[0]
    total_occurrences = cluster_aliases['number_of_occurrences'].sum()
    # Most popular alias
    n1_row = cluster_aliases.sort_values('number_of_occurrences', ascending=False).iloc[0]
    results.append({
        'ema_full_name': ema_row['full_name'],
        'ema_object_id': ema_row['object_id'],
        'assigned_cluster': assigned_cluster,
        'distance_to_closest': dists[min_idx],
        'closest': closest_row['full_name'],
        'closest_nb_occ': closest_row['number_of_occurrences'],
        'total_aliases': total_aliases,
        'total_occurrences': total_occurrences,
        'N1_alias': n1_row['full_name'],
        'N1_alias_nb_occ': n1_row['number_of_occurrences'],
    })
results_df = pd.DataFrame(results)
display(results_df.head())
# Out:
# 100%|██████████| 237/237 [00:49<00:00,  4.82it/s]
#                                        ema_full_name  \
# 0  Clinical Practice Research Datalink (CPRD) GOL...
# 1  Cancer Registry of Instituto Português de Onco...
# 2  European Registry of Patients with McArdle dis...
# 3  The UK-Irish Atopic Eczema Systemic Therapy Re...
# 4     syndena GmbH (former OncoTyrol) (syndena GmbH)
#
#                           ema_object_id assigned_cluster  distance_to_closest  \
# 0  028ac269-7f7f-56d3-8dd3-0bd93913d864             70_3             0.007017
# 1  0446b0c0-0bec-5999-8c59-f0e4107dabc3              0_0             0.043343
# 2  060d06a8-0a14-5b8b-9fe4-882f08412d7f             3354             0.010645
# 3  060ede1e-35d6-5dab-9e1e-d7e1e2f78c2a             5482             0.005611
# 4  08920b82-907a-5d03-828e-f76f7b3c735e            144_0             0.179240
#
#                                              closest  closest_nb_occ  \
# 0  Clinical Practice Research Datalink GOLD (CPRD...              11
# 1                    Herzinfarktverbund Essen (HIVE)               1
# 2  European registry for patients with McArdle di...               2
# 3                        Texas Trauma Registry (TTR)               1
# 4                     Cancer Registry of Tyrol (CRT)               5
#
#    total_aliases  total_occurrences  \
# 0              2                 12
# 1          12453              17753
# 2              2                  3
# 3              2                  2
# 4              3                  7
#
#                                             N1_alias  N1_alias_nb_occ
# 0  Clinical Practice Research Datalink GOLD (CPRD...               11
# 1                          Fushimi AF Registry (FAR)               77
# 2  European registry for patients with McArdle di...                2
# 3                        Texas Trauma Registry (TTR)                1
# 4                     Cancer Registry of Tyrol (CRT)                5

# %% [markdown]
# ## 5. Save Results
# Save the results DataFrame to Excel for further analysis.

# %%
results_xlsx = 'data/W02/R03_evaluate_model_performance_on_ema_registries/ema_prediction_results.xlsx'
# make sure the directory exists
results_dir = Path(results_xlsx).parent
results_dir.mkdir(parents=True, exist_ok=True)
results_df.to_excel(results_xlsx, index=False)
print(f'Results saved to {results_xlsx}')
# Out:
# Results saved to data/W02/R03_evaluate_model_performance_on_ema_registries/ema_prediction_results.xlsx

# %% [markdown]
# ## 6. Analysis & Metrics
# Reload the results and compute the required metrics.

# %%
# Reload results
results_xlsx = 'data/W02/R03_evaluate_model_performance_on_ema_registries/ema_prediction_results.xlsx'
results_df = pd.read_excel(results_xlsx)
# Identify noise clusters: '0' or ending with '_0'
def is_noise(cluster):
    return str(cluster) == '0' or str(cluster).endswith('_0')
results_df['is_noise'] = results_df['assigned_cluster'].apply(is_noise)
# EMA transformation rate
n_total = results_df.shape[0]
# add a column 'identical' to check if the closest alias is the same as the EMA registry    
results_df['identical'] = results_df['ema_full_name'] == results_df['closest']
# count how many EMA registries are identical to the closest alias
n_identical = results_df['identical'].sum()
print(f'Number of identical EMA registries: {n_identical} ({(n_identical / n_total)*100:.1f}%)')
# Count how many EMA registries are in noise
n_noise = results_df['is_noise'].sum()
print(f'Number of EMA registries in noise clusters: {n_noise} ({(n_noise / n_total)*100:.1f}%)')
n_transformed = (~results_df['is_noise']).sum()
ema_transformation_rate = n_transformed / n_total
print(f'EMA transformation rate: {ema_transformation_rate*100:.1f}% ({n_transformed}/{n_total})')
# Number of clusters with at least one EMA registry
transformed_clusters = results_df.loc[~results_df['is_noise'], 'assigned_cluster'].unique()
n_clusters_with_ema = len(transformed_clusters)
print(f'Number of clusters with at least one EMA registry: {n_clusters_with_ema}')
# Clusters with multiple EMA registries
cluster_counts = results_df.loc[~results_df['is_noise'], 'assigned_cluster'].value_counts()
multi_ema_clusters = cluster_counts[cluster_counts > 1]
print(f'Clusters with multiple EMA registries: {multi_ema_clusters.to_dict()}')
# Aliases per transformed EMA registry
aliases_stats = results_df.loc[~results_df['is_noise'], 'total_aliases'].describe()
print('Aliases per transformed EMA registry:')
print(aliases_stats)
# Out:
# Number of identical EMA registries: 21 (8.9%)
# Number of EMA registries in noise clusters: 73 (30.8%)
# EMA transformation rate: 69.2% (164/237)
# Number of clusters with at least one EMA registry: 126
# Clusters with multiple EMA registries: {'0_1': 24, '4032': 8, '6_3': 5, '26_1': 2, '4449': 2, '0_1167': 2, '534_1': 2}
# Aliases per transformed EMA registry:
# count     164.000000
# mean      794.585366
# std      1856.610980
# min         2.000000
# 25%         2.000000
# 50%         3.000000
# 75%        13.250000
# max      5256.000000
# Name: total_aliases, dtype: float64

# %%
# display the 10 first rows of transformed_clusters ranked by total_aliases
transformed_clusters_df = results_df.loc[~results_df['is_noise']].sort_values('total_aliases', ascending=False)
display(transformed_clusters_df.head(50)[['ema_full_name', 'closest', 'closest_nb_occ','assigned_cluster', 'total_aliases', 'total_occurrences']])
# Out:
#                                          ema_full_name  \
# 39                             FranceCoag (FranceCoag)
# 19   Global Registry for COL6-related Dystrophies (...
# 8                                       LynxCare (LXC)
# 7                       Telotron - Telomera (Telotron)
# 38                        AOUPR EHDEN Database (AOUPR)
# 37   Health Data Architecture for Learning, INFOBAN...
# 34   CureDRPLA Global Patient Registry (CureDRPLA G...
# 27   Institut Municipal d'Assistència Sanitària Inf...
# 172  The European HBV Registry - A joint initiative...
# 183  The United Kingdom Spinal Muscular Atrophy Pat...
# 215  Dutch Haemophilia Registry (HemoNED - Haemophi...
# 194  Clinical Hospital Center Zvezdara - Heliant (C...
# 230             Casa di Cura Igea OMOP CDM (CCI - CDM)
# 110                          RIOJA SALUD (RIOJA SALUD)
# 109                  Hospitalizations database (Spain)
# 119  CENTOGENE Biodatabank in Parkinson Disease (CN...
# 121  International Cartilage Regeneration & Joint P...
# 112         Big Data in Healthcare from Aragon (BiGAN)
# 68   INvestigating SIGnificant Health TrendS in pro...
# 71                               US Open Claims (DxHx)
# 143  Health Data Research Platform of the Balearic ...
# 147  Hospital Universitario Virgen Macarena EHR (HUVM)
# 185         Team Gesundheit GKV Claims data (GKV, SHI)
# 163                  Ukrainian Lymphoma Registry (ULR)
# 45      The Norwegian Prescribed Drug Registry (NorPD)
# 207  Danish registries (access/analysis) (Danish re...
# 69   Sweden National Prescribed Drugs Register / Lä...
# 70   Landspatientregisteret (National Patient Regis...
# 60   Initiative for Quality Improvement and Epidemi...
# 222  Sweden National Cancer Register / Cancerregist...
# 149  European network of population-based registrie...
# 84        UK Cystic Fibrosis Registry (UK CF Registry)
# 106  British Society for Rheumatology Biologics Reg...
# 135                    Danny Platform (Danny Platform)
# 116                The Cancer Registry of Norway (CRN)
# 93   Système National des Données de Santé (French ...
# 206                        Prostate Cancer Observatory
# 233  Terveydenhuollon hoitoilmoitusrekisteri (Finla...
# 213  EURAP International Registry of Antiepileptic ...
# 200         Auria Clinical Informatics (FinOMOP) (ACI)
# 108                  Netherlands Cancer Registry (NCR)
# 150                          Galilee - Kineret (GKHDL)
# 51                   Hospital Episode Statistics (HES)
# 31   Extended Cohort for E-health, Environment and ...
# 63     Czech Registry of Monoclonal Gammopathies (RMG)
# 17   Enroll-HD: A Prospective Registry Study in a G...
# 6    European Cystic Fibrosis Society Patient Regis...
# 98   ERN RARE-LIVER prospective research registry (...
# 111               Danish Health Data Registries (DKHD)
# 83   REGISTRY: a study by the European Huntington’s...
#
#                                                closest  closest_nb_occ  \
# 39                             FranceCoag (FranceCoag)               3
# 19       Nationwide, prospective, multicentre registry               1
# 8    North East Thames Regional Health Authority Ce...               1
# 7     Institute of Toxicology of Madrid Registry (ITM)               1
# 38        Odense University Hospital Databases (OUHDB)               1
# 37        Colombian Ministry of Health Database (CMHD)               1
# 34   Stanford Atrial Fibrillation Registry (Stanfor...               1
# 27   Catalan Medical Evaluations Institute database...               1
# 172                    HBV Diagnostic Registry (HBVDR)               1
# 183                      Pavia Diabetes Registry (PDR)               1
# 215  National Hemophilia Registry of the Netherland...               1
# 194  Central Health Information System of the Repub...               1
# 230    California Neural Tube Defect Registry (CALNTD)               1
# 110  Regional Register of AIDS cases in La Rioja (R...               1
# 109                          Bacteraemia Register (BR)               1
# 119  Swedish National HPV Vaccination Registry (SNHVR)               1
# 121  China National Tuberculosis Surveillance Syste...               1
# 112  Public Data Analysis for Health Research and I...               1
# 68       Oyabe Health District Stroke Registry (OHDSR)               1
# 71         STent Anti-thrombotic Regimen Study (STARS)               1
# 143  Public Data Analysis for Health Research and I...               1
# 147  Helsinki University Hospital Medical Records (...               1
# 185  German Statutory Health Insurance Registry (GS...               1
# 163                  Ukrainian Lymphoma Registry (ULR)               3
# 45         The Norwegian Prescription Database (NorPD)               3
# 207                           Danish Health Registries               6
# 69   Swedish National Prescribed Drug Register (SNPDR)               6
# 70           Norwegian National Patient Register (NPR)               3
# 60           Danish Nationwide Patient Registry (DNPR)               1
# 222             Swedish National Cancer Register (NCR)              18
# 149  European network of population-based registrie...               3
# 84   Veterans Health Administration (VA) HCV Regist...               1
# 106  British Society for Rheumatology Biologics Reg...              19
# 135  Maternal Fetal Medicine Units Cesarean Registr...               1
# 116                The Cancer Registry of Norway (CRN)              14
# 93        Système National des Données de Santé (SNDS)              13
# 206           German Clinical Cancer Registries (GCCR)               1
# 233  Society of Thoracic Surgeons Congenital Cardia...               1
# 213  European Registry of Antiepileptic drugs and P...               9
# 200  Global Registry of Acute Coronary Syndrome (GR...               4
# 108                  Netherlands Cancer Registry (NCR)             996
# 150  Northern New England Cardiac Surgery Registry ...               1
# 51                   Hospital Episode Statistics (HES)             135
# 31   Swedish National Register for Systemic Treatme...               4
# 63     Czech Registry of Monoclonal Gammopathies (RMG)              12
# 17   European Huntington's Disease Network's REGIST...               4
# 6    European Cystic Fibrosis Society Patient Regis...              32
# 98   Kaiser Permanente Northern and Southern Califo...               1
# 111         Danish National Nephrology Registry (DNNR)               1
# 83   European Huntington's Disease Network's REGIST...               4
#
#     assigned_cluster  total_aliases  total_occurrences
# 39               0_1           5256               8651
# 19               0_1           5256               8651
# 8                0_1           5256               8651
# 7                0_1           5256               8651
# 38               0_1           5256               8651
# 37               0_1           5256               8651
# 34               0_1           5256               8651
# 27               0_1           5256               8651
# 172              0_1           5256               8651
# 183              0_1           5256               8651
# 215              0_1           5256               8651
# 194              0_1           5256               8651
# 230              0_1           5256               8651
# 110              0_1           5256               8651
# 109              0_1           5256               8651
# 119              0_1           5256               8651
# 121              0_1           5256               8651
# 112              0_1           5256               8651
# 68               0_1           5256               8651
# 71               0_1           5256               8651
# 143              0_1           5256               8651
# 147              0_1           5256               8651
# 185              0_1           5256               8651
# 163              0_1           5256               8651
# 45               6_3            690              13003
# 207              6_3            690              13003
# 69               6_3            690              13003
# 70               6_3            690              13003
# 60               6_3            690              13003
# 222              6_2             68               1075
# 149             6_74             44                241
# 84             133_2             32                 55
# 106            772_1             23                130
# 135            194_1             22                 52
# 116             6_19             21                685
# 93            1558_1             17                 51
# 206             6_28             16                 84
# 233             9_17             14                 51
# 213            673_1             14                 49
# 200             27_1             14                703
# 108             6_29             14               1076
# 150            825_1             13                 34
# 51              69_1             12                165
# 31              6_47             10                 24
# 63            1636_1              9                 23
# 17              26_1              8                 70
# 6              235_2              8                 63
# 98             856_1              8                 61
# 111             6_70              8                 25
# 83              26_1              8                 70
