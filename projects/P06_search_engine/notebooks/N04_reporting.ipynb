# %%
import os
import mlflow
import plotly.express as px

from p06_search_engine import config

# %%
# setup mlflow
os.chdir(config.PATH_PROJECT)
mlflow.set_tracking_uri(config.MLFLOW_URI)
mlflow.set_experiment(config.MLFLOW_EXPERIMENT_NAME)
# Out:
# <Experiment: artifact_location='file:///home/jperrio/registry_data_catalog_experiments/projects/P06_search_engine/mlruns/232264857835789669', creation_time=1755763493203, experiment_id='232264857835789669', last_update_time=1755763493203, lifecycle_stage='active', name='search_engine', tags={}>

# %%
# load results from mlflow
df_benchmarks = mlflow.search_runs(filter_string="status = 'FINISHED'")

# process results
df_benchmarks = (
    df_benchmarks
    
    # keep only relevant columns (id, parameters and metrics)
    [[
        "tags.mlflow.runName", 
        *df_benchmarks.columns[df_benchmarks.columns.str.startswith("params.")], 
        *df_benchmarks.columns[df_benchmarks.columns.str.startswith("metrics.")], 
    ]]

    # convert values to correct types
    .where(lambda df: df.ne("None"))
    .astype(float, errors="ignore")
    .assign(**{"params.searching_distance": lambda df: df["params.searching_distance"].str.split(".").str[-1].str.replace("_", "-").str.lower()})
    .assign(**{"params.searching_tokenization": lambda df: df["params.searching_tokenization"].str.split(".").str[-1].str.replace("_", "-").str.lower()})
    .assign(**{"params.searching_fusion_type": lambda df: df["params.searching_fusion_type"].str.split(".").str[-1].str.replace("_", "-").str.lower()})

    #.loc[lambda df: df["params.locations"].isna() | df["params.locations"].eq("None") | df["params.locations"].eq(False)] #FIXME

    .sort_values("metrics.searching_map", ascending=False)
)
display(df_benchmarks)
# Out:
#                                    tags.mlflow.runName  \
# 201  name_acronym_locations1_conditions3___vector_d...
# 198  name_acronym_locations1_conditions5___vector_d...
# 213   name_acronym_conditions3___vector_distanceCOSINE
# 210   name_acronym_conditions5___vector_distanceCOSINE
# 165           name_conditions5___vector_distanceCOSINE
# ..                                                 ...
# 48   name_acronym___hybrid_distanceHAMMING_tokeniza...
# 49   name_acronym___hybrid_distanceHAMMING_tokeniza...
# 33   name_acronym_conditions1___vector_distanceHAMMING
# 234                      name___vector_distanceHAMMING
# 239              name_acronym___vector_distanceHAMMING
#
#     params.preparing_locations params.preparing_conditions  \
# 201                          1                           3
# 198                          1                           5
# 213                          0                           3
# 210                          0                           5
# 165                          0                           5
# ..                         ...                         ...
# 48                           0                           0
# 49                           0                           0
# 33                           0                           1
# 234                       None                        None
# 239                       None                        None
#
#     params.searching_tokenization params.searching_fusion_type  \
# 201                          None                         None
# 198                          None                         None
# 213                          None                         None
# 210                          None                         None
# 165                          None                         None
# ..                            ...                          ...
# 48                        trigram                       ranked
# 49                        trigram               relative-score
# 33                           None                         None
# 234                          None                         None
# 239                          None                         None
#
#     params.searching_method params.searching_distance params.searching_alpha  \
# 201                  vector                    cosine                   None
# 198                  vector                    cosine                   None
# 213                  vector                    cosine                   None
# 210                  vector                    cosine                   None
# 165                  vector                    cosine                   None
# ..                      ...                       ...                    ...
# 48                   hybrid                   hamming                   0.75
# 49                   hybrid                   hamming                   0.75
# 33                   vector                   hamming                   None
# 234                  vector                   hamming                   None
# 239                  vector                   hamming                   None
#
#     params.preparing_acronym params.preparing_name  \
# 201                     True                  True
# 198                     True                  True
# 213                     True                  True
# 210                     True                  True
# 165                    False                  True
# ..                       ...                   ...
# 48                      True                  True
# 49                      True                  True
# 33                      True                  True
# 234                    False                  True
# 239                     True                  True
#
#     params.thresholding_relevance params.thresholding_rank  \
# 201          -0.21527457833290098                       46
# 198          -0.21516536474227904                       37
# 213          -0.21644224166870119                       41
# 210          -0.21136171340942383                       32
# 165          -0.21541929841041563                       38
# ..                            ...                      ...
# 48            0.06556109994649884                     None
# 49             0.0649556890130043                     None
# 33                           None                        1
# 234                       -1023.0                     None
# 239                       -1023.0                     None
#
#      metrics.thresholding_recall  metrics.thresholding_precision  \
# 201                     0.540069                        0.417567
# 198                     0.517894                        0.424201
# 213                     0.510450                        0.431164
# 210                     0.449053                        0.473841
# 165                     0.509558                        0.495438
# ..                           ...                             ...
# 48                      0.221750                        0.013830
# 49                      0.216982                        0.014021
# 33                      0.003922                        0.019608
# 234                     0.072194                        0.002431
# 239                     0.103245                        0.002627
#
#      metrics.searching_map  metrics.thresholding_f1  \
# 201               0.585359                 0.401651
# 198               0.581011                 0.397497
# 213               0.573250                 0.404193
# 210               0.565811                 0.395670
# 165               0.564241                 0.435978
# ..                     ...                      ...
# 48                0.009347                 0.024945
# 49                0.007530                 0.025253
# 33                0.005074                 0.006536
# 234               0.000982                 0.004570
# 239               0.000945                 0.004954
#
#      metrics.thresholding_n_registries
# 201                          19.294118
# 198                          16.784314
# 213                          18.156863
# 210                          13.647059
# 165                          17.686275
# ..                                 ...
# 48                          280.000000
# 49                          280.039216
# 33                            1.000000
# 234                         500.000000
# 239                         500.000000
#
# [243 rows x 17 columns]

# %%
df = df_benchmarks.copy()

# %%
### Visualize performances ###

for metric_name in ["metrics.searching_map"]:
    fig = (
        px.bar(
            df, 
            x="tags.mlflow.runName", 
            y=metric_name, 
            color="params.searching_method", 
            text_auto=".3f", 

            category_orders={"tags.mlflow.runName": df["tags.mlflow.runName"].tolist()}, 
            labels={
                metric_name: metric_name.split(".")[-1].replace("_", " ").title(), 
                "params.searching_method": "Method", 
                "tags.mlflow.runName": "Experiment", 
            }, 
            title=f"Performances by experiment on metric: <i>'{metric_name.split('.')[-1].replace('_', ' ').lower()}'</i>", 
            template="plotly_white", 
        )
        .update_xaxes(tickfont_size=7.5)
        .update_yaxes(rangemode="tozero").add_hline(0, line_dash="solid").add_hline(1, line_dash="dot")
    )
    fig.show()

# %%
def plot_parameter_comparison(df, param_name, metric_name, filter=False):

    if filter:
        df = (
            df

            .assign(n=lambda df: (
                df
                .groupby(df.columns[df.columns.str.startswith("params.") & ~df.columns.str.startswith("params.thresholding") & (df.columns != param_name)].tolist(), dropna=False)
                ["params.searching_distance"]
                .transform("nunique")
            ))
            .loc[lambda df: df["n"] == df["n"].max()]
        )

    df = df.groupby(list(set([param_name, "params.searching_method"])))[metric_name].describe().sort_values("mean", ascending=False).reset_index()
    fig = (
        px.bar(
            df, 
            x="params.searching_method", 
            y="mean", error_y="std", 
            color=param_name, 
            barmode="group", 
            text_auto=".3f", 
            color_discrete_map={
                False: "lightcoral", 
                True: "lightgreen", 
                1: "lightgreen", 
                3: "green", 
                5: "darkgreen", 
            }, 
            color_discrete_sequence=px.colors.qualitative.Alphabet, 
            category_orders={
                "params.searching_method": df["params.searching_method"].drop_duplicates().tolist(), 
                param_name: df[param_name].drop_duplicates().tolist(), 
            },
            labels={
                "mean": metric_name.split(".")[-1].replace("_", " ").title(), 
                param_name: param_name.split(".")[-1].replace("_", " ").title(), 
                "params.searching_method": "Method", 
            }, 
            title=f"Comparison of performances by parameter: <i>'{param_name.split('.')[-1].replace('_', ' ').lower()}'</i>", 
            template="plotly_white", 
        )
        .update_yaxes(rangemode="tozero").add_hline(0, line_dash="solid").add_hline(1, line_dash="dot")
    )
    fig.show()



metric_name = "metrics.searching_map"

# Vector search
## distance
plot_parameter_comparison(df.loc[df["params.searching_method"].eq("vector")], param_name="params.searching_distance", metric_name=metric_name, filter=True)
df = df.loc[df["params.searching_distance"].eq("cosine") | df["params.searching_distance"].isna()]

# Keyword search
## tokenization
plot_parameter_comparison(df.loc[df["params.searching_method"].eq("keyword")], param_name="params.searching_tokenization", metric_name=metric_name, filter=True)
df = df.loc[df["params.searching_tokenization"].eq("trigram") | df["params.searching_tokenization"].isna()]

# Hybrid search
## alpha
plot_parameter_comparison(df, param_name="params.searching_alpha", metric_name=metric_name, filter=True)
plot_parameter_comparison(df, param_name="params.searching_fusion_type", metric_name=metric_name, filter=True)
df = df.loc[df["params.searching_alpha"].eq("0.75") | df["params.searching_alpha"].isna()]
df = df.loc[df["params.searching_fusion_type"].eq("ranked") | df["params.searching_fusion_type"].isna()]

# Searching
## method
plot_parameter_comparison(df, param_name="params.searching_method", metric_name=metric_name)

# Preparing
## acronym
plot_parameter_comparison(df, param_name="params.preparing_acronym", metric_name=metric_name)
plot_parameter_comparison(df, param_name="params.preparing_locations", metric_name=metric_name)
plot_parameter_comparison(df, param_name="params.preparing_conditions", metric_name=metric_name)

# %%
import numpy as np
import pandas as pd
from p06_search_engine import io

TOP_K = 100

df_annotations = pd.read_json(config.PATH_DATA_2ND_ANNOTATIONS)

dfs = []
for experiment_name in ["name_acronym_locations1_conditions3___vector_distanceCOSINE"]:
    df_searches = pd.read_json(f"{config.PATH_DATA_SEARCHES}/{experiment_name}.json")

    df = (
        df_searches
        .merge(df_annotations, on=["query_id", "registry_id"], how="outer")
        
        .sort_values(by=["query_id", "registry_id"])

        .assign(search_rank=lambda df: df["search_rank"].fillna(np.inf))
        .assign(annotation_label=lambda df: pd.Categorical(df["annotation_label"], categories=["YES", "NO"], ordered=True))
        .sort_values(["query_id", "search_rank"])

        .assign(
            k=lambda df: df["search_rank"].fillna(np.inf), 
            y=lambda df: df["annotation_label"] == "YES", 
            precision_k=lambda df: df.groupby("query_id")["y"].transform("cumsum") / df["k"], 
            recall_k=lambda df: df.groupby("query_id")["y"].transform("cumsum") / df.groupby("query_id")["y"].transform("sum"), 
        )

        .groupby("k")
        [["precision_k", "recall_k"]]
        .mean()

        .head(TOP_K)

        .assign(experiment_name=experiment_name)
        .reset_index()
        [["experiment_name", "k", "precision_k", "recall_k"]]
    )
    dfs.append(df)

df = pd.concat(dfs, ignore_index=True)

for metric_name in ["precision_k", "recall_k"]:
    fig = (
        px.line(
            df, 
            x="k", 
            y=metric_name, 
            color="experiment_name", 
            labels={"precision_k": "Precision@k", "recall_k": "Recall@k"}, 
            color_discrete_sequence=px.colors.qualitative.Alphabet, 
            category_orders={"experiment_name": df["experiment_name"].tolist()}, 
            title=f"Performance on metric: <i>'{metric_name}'</i> by experiment",
            template="plotly_white", 
        )
        .update_xaxes(rangemode="tozero").update_yaxes(rangemode="tozero").add_hline(1, line_dash="dot")
    )
    fig.show()

# %%
import numpy as np
import pandas as pd
import plotly.express as px

from p06_search_engine import config

df_queries = pd.read_json(config.PATH_DATA_2ND_QUERIES)
df_registries = pd.read_json(config.PATH_DATA_REGISTRIES)

experiment_name = "name_acronym_locations1_conditions3___vector_distanceCOSINE"
df_searches = pd.read_json(f"{config.PATH_DATA_SEARCHES}/{experiment_name}.json")
df_annotations = pd.read_json(config.PATH_DATA_2ND_ANNOTATIONS)

df = (
    df_searches

    .merge(df_annotations, on=["query_id", "registry_id"], how="outer")
    .merge(df_registries, on="registry_id", how="left")
    .merge(df_queries, on="query_id", how="left")
    
    .sort_values(by=["query_id", "registry_id"])

    .assign(search_rank=lambda df: df["search_rank"].fillna(np.inf))
    .assign(annotation_label=lambda df: pd.Categorical(df["annotation_label"], categories=["YES", "NO"], ordered=True))
    .sort_values(["query_id", "search_rank"])
)

df = (
    df

    .assign(
        k=lambda df: df["search_rank"].fillna(np.inf), 
        y=lambda df: df["annotation_label"] == "YES", 
        precision_k=lambda df: df.groupby("query_id")["y"].transform("cumsum") / df["k"], 
        recall_k=lambda df: df.groupby("query_id")["y"].transform("cumsum") / df.groupby("query_id")["y"].transform("sum"), 
        f1_k=lambda df: 2 * (df["precision_k"] * df["recall_k"] / (df["precision_k"] + df["recall_k"])).fillna(0), 
    )
)

s_plot = df.loc[lambda df: df["annotation_label"].eq("YES")].groupby(["query_id", "query_text"])["precision_k"].mean().reset_index().sort_values("precision_k")
display(s_plot["precision_k"].mean())
px.bar(
    s_plot, 
    x="query_id", 
    y="precision_k", 
    text_auto=".3f", 
    hover_data=["query_id", "query_text"], 
    title="MeanAveragePrecision by query", 
    template="plotly_white", 
).add_hline(s_plot["precision_k"].mean(), annotation_text="mean").add_hline(s_plot["precision_k"].median(), line_dash="dot", annotation_text="median").show()

# %% [raw]
# print("RANKS:")
# results = []
# for rank_threshold in range(1, 50+1):
#     result = (
#         df
#         .loc[lambda df: df["search_rank"] <= rank_threshold]
#         .drop_duplicates("query_id", keep="last")
#         ["f1_k"]
#         .agg(["mean", "median"])
#     )
#     results.append({"rank_threshold": rank_threshold, **result.to_dict()})
# df_results = pd.DataFrame(results).sort_values("rank_threshold")
# px.line(df_results, x="rank_threshold", y=["mean", "median"], title="F1 by threshold on <i>rank</i>.").show()
# display(df_results.sort_values("mean", ascending=False).head(1))
# display(df_results.sort_values("median", ascending=False).head(1))
# ranks_rank_threshold_mean = df.loc[lambda df: df["search_rank"] <= df_results.set_index("rank_threshold")["mean"].idxmax()].groupby("query_id")["search_rank"].max().rename("rank_threshold_mean")
# ranks_rank_threshold_median = df.loc[lambda df: df["search_rank"] <= df_results.set_index("rank_threshold")["median"].idxmax()].groupby("query_id")["search_rank"].max().rename("rank_threshold_median")
#
#
#
# def f(df, threshold):
#     df = df.loc[lambda df: df["search_distance"] <= threshold]
#     if df.empty:
#         return 0
#     return df.iloc[-1]["f1_k"]
#
# print("DISTANCES:")
# results = []
# for distance_threshold in np.linspace(df["search_distance"].min(), df["search_distance"].max(), 100+1):
#     result = (
#         df
#         .groupby("query_id").apply(lambda df, distance_threshold=distance_threshold: f(df, distance_threshold))
#         .agg(["mean", "median"])
#     )
#     results.append({"distance_threshold": distance_threshold, **result.to_dict()})
# display(df)
# df_results = pd.DataFrame(results).sort_values("distance_threshold").dropna()
# px.line(df_results, x="distance_threshold", y=["mean", "median"], title="F1 by threshold on <i>distance</i>.").show()
# display(df_results.sort_values("mean", ascending=False).head(1))
# display(df_results.sort_values("median", ascending=False).head(1))
# ranks_distance_threshold_mean = df.loc[lambda df: df["search_distance"] <= df_results.set_index("distance_threshold")["mean"].idxmax()].groupby("query_id")["search_rank"].max().rename("distance_threshold_mean")
# ranks_distance_threshold_median = df.loc[lambda df: df["search_distance"] <= df_results.set_index("distance_threshold")["median"].idxmax()].groupby("query_id")["search_rank"].max().rename("distance_threshold_median")
#
# print("RANKS AND DISTANCES:")
# results = []
# for rank_threshold in range(1, 50+1):
#     for distance_threshold in np.quantile(df["search_distance"].dropna(), np.linspace(0, 1, 100+1)):
#         result = (
#             df
#             .loc[lambda df: (df["search_rank"] <= rank_threshold) & (df["search_distance"] <= distance_threshold)]
#             .drop_duplicates("query_id", keep="last")
#             ["f1_k"]
#             .agg(["mean", "median"])
#         )
#         results.append({"rank_threshold": rank_threshold, "distance_threshold": distance_threshold, **result.to_dict()})
# df_results = pd.DataFrame(results).sort_values(["rank_threshold", "distance_threshold"]).dropna()
# display(df_results.sort_values("mean", ascending=False).head(1))
# display(df_results.sort_values("median", ascending=False).head(1))
# ranks_and_threshold_mean = df.loc[lambda df: (df["search_rank"] <= df_results.set_index(["rank_threshold", "distance_threshold"])["mean"].idxmax()[0]) & (df["search_distance"] <= df_results.set_index(["rank_threshold", "distance_threshold"])["mean"].idxmax()[1])].groupby("query_id")["search_rank"].max().rename("and_threshold_mean")
# ranks_and_threshold_median = df.loc[lambda df: (df["search_rank"] <= df_results.set_index(["rank_threshold", "distance_threshold"])["median"].idxmax()[0]) & (df["search_distance"] <= df_results.set_index(["rank_threshold", "distance_threshold"])["median"].idxmax()[1])].groupby("query_id")["search_rank"].max().rename("and_threshold_median")
#
# """print("RANKS OR DISTANCES:")
# results = []
# for rank_threshold in range(1, 50+1):
#     for distance_threshold in np.arange(0.0, 1.01, 0.01):
#         result = (
#             df
#             .loc[lambda df: (df["search_rank"] <= rank_threshold) | (df["search_distance"] <= distance_threshold)]
#             .drop_duplicates("query_id", keep="last")
#             ["f1_k"]
#             .agg(["mean", "median"])
#         )
#         results.append({"rank_threshold": rank_threshold, "distance_threshold": distance_threshold, **result.to_dict()})
# df_results = pd.DataFrame(results).sort_values(["rank_threshold", "distance_threshold"]).dropna()
# display(df_results.sort_values("mean", ascending=False).head(1))
# display(df_results.sort_values("median", ascending=False).head(1))
# ranks_or_threshold_mean = df.loc[lambda df: (df["search_rank"] <= df_results.set_index(["rank_threshold", "distance_threshold"])["mean"].idxmax()[0]) | (df["search_distance"] <= df_results.set_index(["rank_threshold", "distance_threshold"])["mean"].idxmax()[1])].groupby("query_id")["search_rank"].max().rename("or_threshold_mean")
# ranks_or_threshold_median = df.loc[lambda df: (df["search_rank"] <= df_results.set_index(["rank_threshold", "distance_threshold"])["median"].idxmax()[0]) | (df["search_distance"] <= df_results.set_index(["rank_threshold", "distance_threshold"])["median"].idxmax()[1])].groupby("query_id")["search_rank"].max().rename("or_threshold_median")"""
#
# df_nb_outputs = pd.concat(
#     [
#         ranks_rank_threshold_mean,
#         ranks_rank_threshold_median,
#         ranks_distance_threshold_mean,
#         ranks_distance_threshold_median,
#         ranks_and_threshold_mean,
#         ranks_and_threshold_median,
#         #ranks_or_threshold_mean,
#         #ranks_or_threshold_median
#     ],
#     axis=1,
# )
# px.box(df_nb_outputs, title="Distribution of number of proposed registries.").show()

# %%
px.bar(df_annotations.groupby("query_id")["annotation_label"].value_counts().unstack("annotation_label").fillna(0)["YES"].sort_values())
