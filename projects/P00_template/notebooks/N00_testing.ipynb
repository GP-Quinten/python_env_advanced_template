# %%
# Auto-reload modules when code is modified
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Check that modules defined in p00-template are properly installed (test with scikit-learn)

# %%
import sklearn
print(f"scikit-learn version: {sklearn.__version__}")

# %% [markdown]
# Check that modules defined in root-project-template are properly installed (test with pandas)

# %%
import pandas
print(f"pandas version: {pandas.__version__}")

# %% [markdown]
# Check that packaged code is properly installed

# %% [markdown]
# First from local development project (p00_template)

# %%
# import a custom module specific to this project
from p00_template.hello_world import hello_message
# Print the hello world message from your module
message = hello_message()
print(message)

# %% [markdown]
# Then from the root project/env (root_project_template)

# %%
# import a custom module specific to this project
from root_example_module.hi_there import hi_message
# Print the hello world message from your module
message = hi_message()
print(message)

# %% [markdown]
# Is plotly installed? No -> add it to pyproject.toml and install it by running poetry add 'plotly' then poetry install

# %%
import plotly
print(f"plotly version: {plotly.__version__}")

# %% [markdown]
# Finally check that Quinten package (llm_backends) was properly installed

# %%
import llm_backends
print(f"llm_backends version: {llm_backends.__version__}")
